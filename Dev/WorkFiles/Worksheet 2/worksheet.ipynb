# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import copy

# %%
N = 50 #number of genes
P = 50 #population size
G = 2000 #number of generations
M = 0.03 #mutation rate

# %%
population = []
offspring = []

crossover = []
mutate = []


total_utilities = {
    "origonal": 0,
    "gladiator": 0,
    "crosspoint": 0,
    "mutate": 0
}


best_fitness = np.zeros(G)
average_fitness = np.zeros(G)

# %%
class individual:
    def __init__(self):
        self.gene = [0]*N
        self.fitness = 0

# %%
def test_function( ind ):
    utility=0
    for i in range(N):
        utility = utility + ind.gene[i]
    return utility

# %%
def test_all(pop):
    total_utility = 0
    for i in pop:
        total_utility = total_utility + test_function(i)

    average_utility = total_utility/len(pop)
    
    return average_utility

# %%
def graph_population(pop, name):
    data = np.array([])
    
    for po in pop:
        data = np.append(data, po.fitness)


    plt.plot(data)
    plt.title(name)
    plt.xlabel("Individual")
    plt.ylabel("Fitness")
    plt.show()
    plt.close()

# %%
def graph_averages():
    height = np.array([])
    average = np.array([])
    
    for i in best_fitness:
        height = np.append(height, i)
    
    for i in average_fitness:
        average = np.append(average, i)


    plt.plot(height, label="Best")
    plt.plot(average, label="Average")
    plt.legend()
    plt.title("Generational Fitness")


    plt.xlabel("Generation")
    plt.ylabel("Fitness")
    plt.show()
    plt.close()

# %%
for x in range (0, P):
    tempgene=[]
    for y in range (0, N):
        tempgene.append( random.randint(0,1))
    newind = individual()
    newind.gene = tempgene.copy()
    population.append(newind)

# %%
def get_height(pop):
    height = 0
    for i in pop:
        if i.fitness > height:
            height = i.fitness

    return height

# %%
def test_population(population, name):
    for pop in population:
        pop.fitness = test_function(pop)
        total_utilities[name] = total_utilities[name] + pop.fitness

# %%
for g in range (0, G):



    print("Generation ", g)

## Test origonal population

    test_population(population, "origonal")
    
    
    
        # print(pop.gene, " ", pop.fitness)



## init gladiator population
    
    for i in range (0, P):
        parent1 = random.randint( 0, P-1 )
        off1 = copy.deepcopy(population[parent1])
        parent2 = random.randint( 0, P-1 )
        off2 = copy.deepcopy(population[parent2])
        if off1.fitness > off2.fitness:
            offspring.append( off1 )
        else:
            offspring.append( off2 )

    ## test gladiator population
    
    test_population(offspring, "gladiator")



## create new copies to allow for easy transfer of data

    crossover = copy.deepcopy(offspring) 
    # mutate = copy.deepcopy(offspring)

## init crossover population

    toff1 = individual()
    toff2 = individual()
    temp = individual()
    for i in range( 0, P, 2 ):
        toff1 = copy.deepcopy(crossover[i])
        toff2 = copy.deepcopy(crossover[i+1])
        temp = copy.deepcopy(crossover[i])
        crosspoint = random.randint(1,N)

        for j in range (crosspoint, N):
            toff1.gene[j] = toff2.gene[j]
            toff2.gene[j] = temp.gene[j]
            
        crossover[i] = copy.deepcopy(toff1)
        crossover[i+1] = copy.deepcopy(toff2)

    ## test crossover population

    test_population(crossover, "crosspoint")




## init mutate population

    for i in range( 0, P ):
        newind = individual()
        newind.gene = []
        for j in range( 0, N ):
            gene = crossover[i].gene[j]
            mutprob = random.random()
            # print("muteprob: ", mutprob)
            if mutprob < M:
                if( gene == 1):
                    gene = 0
                else:
                    gene = 1
            newind.gene.append(gene)
            
        mutate.append(newind)

    ## test mutate population

    test_population(mutate, "mutate")

    







    # graph_population(population, "Origonal")
    # graph_population(offspring, "Offspring Gladiator")
    # graph_population(crossover, "Offspring Crossover")
    # graph_population(mutate, "Offspring Mutation")

    print("Best fitness: ", best_fitness[g-1])
    print("Average fitness: ", average_fitness[g-1])
    print("Total utilities: ", total_utilities)

## copy most fit population to next generation


    # if (total_utilities["gladiator"] > total_utilities["crosspoint"]):
    #     if (total_utilities["gladiator"] > total_utilities["mutate"]):

    #         if (total_utilities["origonal"] > total_utilities["gladiator"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(offspring)
    #             print("Gladiator wins")
    #     else:

    #         if (total_utilities["origonal"] > total_utilities["mutate"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(mutate)
    #             print("Mutate wins")
    # else:
    #     if (total_utilities["crosspoint"] > total_utilities["mutate"]):
    #         if(total_utilities["origonal"] > total_utilities["crosspoint"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(crossover)
    #             print("Crossover wins")
    #     else:
    #         if(total_utilities["origonal"] > total_utilities["mutate"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(mutate)
    #             print("Mutate wins")



    if (total_utilities["mutate"] > total_utilities["origonal"]):
        population = copy.deepcopy(mutate)
        print("Mutate wins")
 


    ## calculate average fitness
    best_fitness[g] = get_height(population)
    average_fitness[g] = test_all(population)

    ## reset total utilities

    total_utilities = {
        "origonal": 0,
        "gladiator": 0,
        "crosspoint": 0,
        "mutate": 0
    }

    ## reset populations

    offspring = []
    crossover = []
    mutate = []



## graph average fitness

graph_averages()
# Out:
# Generation  0
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2341}
# Generation  1
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2322}
# Generation  2
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2324}
# Generation  3
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2302}
# Generation  4
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2325}
# Generation  5
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2412, 'crosspoint': 2412, 'mutate': 2328}
# Generation  6
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2412, 'crosspoint': 2412, 'mutate': 2340}
# Generation  7
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2334}
# Generation  8
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2332}
# Generation  9
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2345}
# Generation  10
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2313}
# Generation  11
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2333}
# Generation  12
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2346}
# Generation  13
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2328}
# Generation  14
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2318}
# Generation  15
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2324}
# Generation  16
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2317}
# Generation  17
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2311}
# Generation  18
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2342}
# Generation  19
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2328}
# Generation  20
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2329}
# Generation  21
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2333}
# Generation  22
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2333}
# Generation  23
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2317}
# Generation  24
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2336}
# Generation  25
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2334}
# Generation  26
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2323}
# Generation  27
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2326}
# Generation  28
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2323}
# Generation  29
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2324}
# Generation  30
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2326}
# Generation  31
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2322}
# Generation  32
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2329}
# Generation  33
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2330}
# Generation  34
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2324}
# Generation  35
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2324}
# Generation  36
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2318}
# Generation  37
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2315}
# Generation  38
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2378, 'crosspoint': 2378, 'mutate': 2315}
# Generation  39
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2317}
# Generation  40
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2347}
# Generation  41
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2315}
# Generation  42
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2337}
# Generation  43
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2328}
# Generation  44
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2408, 'crosspoint': 2408, 'mutate': 2344}
# Generation  45
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2326}
# Generation  46
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2336}
# Generation  47
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2333}
# Generation  48
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2408, 'crosspoint': 2408, 'mutate': 2330}
# Generation  49
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2337}
# Generation  50
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2325}
# Generation  51
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2384, 'crosspoint': 2384, 'mutate': 2313}
# Generation  52
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2413, 'crosspoint': 2413, 'mutate': 2353}
# Generation  53
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2324}
# Generation  54
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2331}
# Generation  55
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2333}
# Generation  56
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2326}
# Generation  57
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2324}
# Generation  58
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2327}
# Generation  59
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2383, 'crosspoint': 2383, 'mutate': 2321}
# Generation  60
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2318}
# Generation  61
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2329}
# Generation  62
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2315}
# Generation  63
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2328}
# Generation  64
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2317}
# Generation  65
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2333}
# Generation  66
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2326}
# Generation  67
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2335}
# Generation  68
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2334}
# Generation  69
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2330}
# Generation  70
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2335}
# Generation  71
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2307}
# Generation  72
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2316}
# Generation  73
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2318}
# Generation  74
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2335}
# Generation  75
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2335}
# Generation  76
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2342}
# Generation  77
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2412, 'crosspoint': 2412, 'mutate': 2332}
# Generation  78
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2329}
# Generation  79
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2330}
# Generation  80
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2327}
# Generation  81
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2320}
# Generation  82
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2333}
# Generation  83
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2334}
# Generation  84
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2323}
# Generation  85
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2323}
# Generation  86
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2332}
# Generation  87
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2345}
# Generation  88
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2316}
# Generation  89
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2320}
# Generation  90
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2333}
# Generation  91
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2380, 'crosspoint': 2380, 'mutate': 2331}
# Generation  92
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2320}
# Generation  93
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2327}
# Generation  94
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2314}
# Generation  95
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2341}
# Generation  96
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2310}
# Generation  97
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2328}
# Generation  98
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2329}
# Generation  99
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2315}
# Generation  100
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2316}
# Generation  101
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2331}
# Generation  102
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2343}
# Generation  103
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2325}
# Generation  104
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2327}
# Generation  105
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2324}
# Generation  106
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2331}
# Generation  107
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2327}
# Generation  108
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2324}
# Generation  109
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2325}
# Generation  110
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2323}
# Generation  111
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2339}
# Generation  112
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2314}
# Generation  113
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2318}
# Generation  114
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2340}
# Generation  115
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2413, 'crosspoint': 2413, 'mutate': 2337}
# Generation  116
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2335}
# Generation  117
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2333}
# Generation  118
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2329}
# Generation  119
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2325}
# Generation  120
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2326}
# Generation  121
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2319}
# Generation  122
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2322}
# Generation  123
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2342}
# Generation  124
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2328}
# Generation  125
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2315}
# Generation  126
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2326}
# Generation  127
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2318}
# Generation  128
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2305}
# Generation  129
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2339}
# Generation  130
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2331}
# Generation  131
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2332}
# Generation  132
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2330}
# Generation  133
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2350}
# Generation  134
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2335}
# Generation  135
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2315}
# Generation  136
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2312}
# Generation  137
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2314}
# Generation  138
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2316}
# Generation  139
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2340}
# Generation  140
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2327}
# Generation  141
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2332}
# Generation  142
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2321}
# Generation  143
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2335}
# Generation  144
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2316}
# Generation  145
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2348}
# Generation  146
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2410, 'crosspoint': 2410, 'mutate': 2341}
# Generation  147
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2333}
# Generation  148
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2334}
# Generation  149
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2325}
# Generation  150
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2327}
# Generation  151
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2312}
# Generation  152
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2342}
# Generation  153
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2333}
# Generation  154
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2335}
# Generation  155
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2315}
# Generation  156
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2320}
# Generation  157
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2336}
# Generation  158
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2416, 'crosspoint': 2416, 'mutate': 2349}
# Generation  159
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2327}
# Generation  160
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2331}
# Generation  161
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2326}
# Generation  162
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2380, 'crosspoint': 2380, 'mutate': 2307}
# Generation  163
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2325}
# Generation  164
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2341}
# Generation  165
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2325}
# Generation  166
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2334}
# Generation  167
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2332}
# Generation  168
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2316}
# Generation  169
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2306}
# Generation  170
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2345}
# Generation  171
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2329}
# Generation  172
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2324}
# Generation  173
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2330}
# Generation  174
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2339}
# Generation  175
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2327}
# Generation  176
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2333}
# Generation  177
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2324}
# Generation  178
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2319}
# Generation  179
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2335}
# Generation  180
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2381, 'crosspoint': 2381, 'mutate': 2320}
# Generation  181
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2355}
# Generation  182
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2333}
# Generation  183
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2320}
# Generation  184
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2329}
# Generation  185
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2339}
# Generation  186
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2328}
# Generation  187
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2314}
# Generation  188
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2354}
# Generation  189
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2409, 'crosspoint': 2409, 'mutate': 2332}
# Generation  190
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2333}
# Generation  191
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2312}
# Generation  192
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2316}
# Generation  193
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2329}
# Generation  194
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2307}
# Generation  195
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2344}
# Generation  196
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2329}
# Generation  197
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2336}
# Generation  198
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2311}
# Generation  199
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2412, 'crosspoint': 2412, 'mutate': 2347}
# Generation  200
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2320}
# Generation  201
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2336}
# Generation  202
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2384, 'crosspoint': 2384, 'mutate': 2332}
# Generation  203
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2336}
# Generation  204
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2320}
# Generation  205
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2328}
# Generation  206
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2330}
# Generation  207
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2323}
# Generation  208
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2325}
# Generation  209
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2318}
# Generation  210
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2339}
# Generation  211
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2411, 'crosspoint': 2411, 'mutate': 2342}
# Generation  212
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2329}
# Generation  213
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2320}
# Generation  214
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2320}
# Generation  215
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2307}
# Generation  216
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2325}
# Generation  217
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2357}
# Generation  218
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2340}
# Generation  219
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2346}
# Generation  220
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2303}
# Generation  221
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2336}
# Generation  222
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2309}
# Generation  223
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2330}
# Generation  224
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2337}
# Generation  225
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2339}
# Generation  226
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2334}
# Generation  227
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2323}
# Generation  228
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2312}
# Generation  229
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2384, 'crosspoint': 2384, 'mutate': 2299}
# Generation  230
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2382, 'crosspoint': 2382, 'mutate': 2319}
# Generation  231
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2335}
# Generation  232
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2316}
# Generation  233
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2343}
# Generation  234
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2326}
# Generation  235
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2325}
# Generation  236
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2335}
# Generation  237
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2345}
# Generation  238
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2315}
# Generation  239
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2325}
# Generation  240
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2408, 'crosspoint': 2408, 'mutate': 2340}
# Generation  241
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2307}
# Generation  242
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2313}
# Generation  243
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2335}
# Generation  244
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2331}
# Generation  245
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2322}
# Generation  246
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2339}
# Generation  247
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2322}
# Generation  248
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2321}
# Generation  249
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2334}
# Generation  250
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2389, 'crosspoint': 2389, 'mutate': 2307}
# Generation  251
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2320}
# Generation  252
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2325}
# Generation  253
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2342}
# Generation  254
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2320}
# Generation  255
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2324}
# Generation  256
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2348}
# Generation  257
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2339}
# Generation  258
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2320}
# Generation  259
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2333}
# Generation  260
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2314}
# Generation  261
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2378, 'crosspoint': 2378, 'mutate': 2306}
# Generation  262
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2314}
# Generation  263
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2352}
# Generation  264
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2317}
# Generation  265
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2322}
# Generation  266
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2344}
# Generation  267
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2383, 'crosspoint': 2383, 'mutate': 2299}
# Generation  268
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2330}
# Generation  269
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2375, 'crosspoint': 2375, 'mutate': 2302}
# Generation  270
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2314}
# Generation  271
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2317}
# Generation  272
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2328}
# Generation  273
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2330}
# Generation  274
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2327}
# Generation  275
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2346}
# Generation  276
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2343}
# Generation  277
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2316}
# Generation  278
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2324}
# Generation  279
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2375, 'crosspoint': 2375, 'mutate': 2305}
# Generation  280
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2327}
# Generation  281
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2342}
# Generation  282
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2384, 'crosspoint': 2384, 'mutate': 2319}
# Generation  283
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2385, 'crosspoint': 2385, 'mutate': 2324}
# Generation  284
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2327}
# Generation  285
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2382, 'crosspoint': 2382, 'mutate': 2316}
# Generation  286
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2377, 'crosspoint': 2377, 'mutate': 2314}
# Generation  287
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2338}
# Generation  288
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2316}
# Generation  289
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2330}
# Generation  290
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2338}
# Generation  291
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2340}
# Generation  292
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2329}
# Generation  293
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2319}
# Generation  294
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2327}
# Generation  295
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2326}
# Generation  296
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2338}
# Generation  297
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2334}
# Generation  298
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2343}
# Generation  299
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2336}
# Generation  300
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2307}
# Generation  301
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2342}
# Generation  302
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2313}
# Generation  303
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2330}
# Generation  304
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2328}
# Generation  305
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2331}
# Generation  306
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2304}
# Generation  307
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2327}
# Generation  308
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2319}
# Generation  309
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2322}
# Generation  310
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2324}
# Generation  311
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2328}
# Generation  312
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2326}
# Generation  313
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2383, 'crosspoint': 2383, 'mutate': 2337}
# Generation  314
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2329}
# Generation  315
# Best fitness:  50.0
# Average fitness:  47.18
# Total utilities:  {'origonal': 2359, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2324}
# Generation  316
# Best fitness:  50.0
# Average fitness:  47.18
# ...
# Generation  1896
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2321}
# Generation  1897
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2330}
# Generation  1898
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2374, 'crosspoint': 2374, 'mutate': 2311}
# Generation  1899
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2338}
# Generation  1900
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2322}
# Generation  1901
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2334}
# Generation  1902
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2316}
# Generation  1903
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2328}
# Generation  1904
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2323}
# Generation  1905
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2339}
# Generation  1906
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2328}
# Generation  1907
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2412, 'crosspoint': 2412, 'mutate': 2351}
# Generation  1908
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2315}
# Generation  1909
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2326}
# Generation  1910
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2353}
# Generation  1911
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2322}
# Generation  1912
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2318}
# Generation  1913
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2345}
# Generation  1914
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2331}
# Generation  1915
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2323}
# Generation  1916
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2330}
# Generation  1917
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2315}
# Generation  1918
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2330}
# Generation  1919
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2307}
# Generation  1920
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2412, 'crosspoint': 2412, 'mutate': 2347}
# Generation  1921
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2329}
# Generation  1922
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2329}
# Generation  1923
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2285}
# Generation  1924
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2323}
# Generation  1925
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2394, 'crosspoint': 2394, 'mutate': 2314}
# Generation  1926
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2326}
# Generation  1927
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2335}
# Generation  1928
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2316}
# Generation  1929
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2310}
# Generation  1930
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2330}
# Generation  1931
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2345}
# Generation  1932
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2340}
# Generation  1933
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2337}
# Generation  1934
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2331}
# Generation  1935
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2390, 'crosspoint': 2390, 'mutate': 2339}
# Generation  1936
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2411, 'crosspoint': 2411, 'mutate': 2339}
# Generation  1937
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2348}
# Generation  1938
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2391, 'crosspoint': 2391, 'mutate': 2330}
# Generation  1939
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2343}
# Generation  1940
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2323}
# Generation  1941
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2320}
# Generation  1942
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2332}
# Generation  1943
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2346}
# Generation  1944
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2338}
# Generation  1945
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2336}
# Generation  1946
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2329}
# Generation  1947
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2380, 'crosspoint': 2380, 'mutate': 2311}
# Generation  1948
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2408, 'crosspoint': 2408, 'mutate': 2336}
# Generation  1949
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2326}
# Generation  1950
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2316}
# Generation  1951
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2413, 'crosspoint': 2413, 'mutate': 2352}
# Generation  1952
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2396, 'crosspoint': 2396, 'mutate': 2334}
# Generation  1953
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2406, 'crosspoint': 2406, 'mutate': 2329}
# Generation  1954
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2331}
# Generation  1955
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2337}
# Generation  1956
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2324}
# Generation  1957
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2314}
# Generation  1958
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2305}
# Generation  1959
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2324}
# Generation  1960
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2339}
# Generation  1961
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2395, 'crosspoint': 2395, 'mutate': 2315}
# Generation  1962
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2313}
# Generation  1963
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2334}
# Generation  1964
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2332}
# Generation  1965
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2330}
# Generation  1966
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2338}
# Generation  1967
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2335}
# Generation  1968
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2334}
# Generation  1969
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2397, 'crosspoint': 2397, 'mutate': 2336}
# Generation  1970
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2338}
# Generation  1971
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2332}
# Generation  1972
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2318}
# Generation  1973
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2343}
# Generation  1974
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2341}
# Generation  1975
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2409, 'crosspoint': 2409, 'mutate': 2342}
# Generation  1976
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2331}
# Generation  1977
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2398, 'crosspoint': 2398, 'mutate': 2334}
# Generation  1978
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2393, 'crosspoint': 2393, 'mutate': 2341}
# Generation  1979
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2400, 'crosspoint': 2400, 'mutate': 2344}
# Generation  1980
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2409, 'crosspoint': 2409, 'mutate': 2342}
# Generation  1981
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2336}
# Generation  1982
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2338}
# Generation  1983
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2320}
# Generation  1984
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2405, 'crosspoint': 2405, 'mutate': 2340}
# Generation  1985
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2387, 'crosspoint': 2387, 'mutate': 2330}
# Generation  1986
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2342}
# Generation  1987
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2336}
# Generation  1988
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2331}
# Generation  1989
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2404, 'crosspoint': 2404, 'mutate': 2330}
# Generation  1990
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2388, 'crosspoint': 2388, 'mutate': 2313}
# Generation  1991
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2399, 'crosspoint': 2399, 'mutate': 2322}
# Generation  1992
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2316}
# Generation  1993
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2402, 'crosspoint': 2402, 'mutate': 2329}
# Generation  1994
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2392, 'crosspoint': 2392, 'mutate': 2328}
# Generation  1995
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2401, 'crosspoint': 2401, 'mutate': 2342}
# Generation  1996
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2403, 'crosspoint': 2403, 'mutate': 2334}
# Generation  1997
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2411, 'crosspoint': 2411, 'mutate': 2332}
# Generation  1998
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2407, 'crosspoint': 2407, 'mutate': 2340}
# Generation  1999
# Best fitness:  49.0
# Average fitness:  47.24
# Total utilities:  {'origonal': 2362, 'gladiator': 2386, 'crosspoint': 2386, 'mutate': 2312}
