# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import copy

# %%
N = 50 #number of genes
P = 50 #population size
G = 100 #number of generations
M = 0.03 #mutation rate

# %%
population = []
offspring = []

crossover = []
mutate = []


total_utilities = {
    "origonal": 0,
    "gladiator": 0,
    "crosspoint": 0,
    "mutate": 0
}


best_fitness = np.zeros(G)
average_fitness = np.zeros(G)

# %%
class individual:
    def __init__(self):
        self.gene = [0]*N
        self.fitness = 0

# %%
def test_function( ind ):
    utility=0
    for i in range(N):
        utility = utility + ind.gene[i]
    return utility

# %%
def test_all(pop):
    total_utility = 0
    for i in pop:
        total_utility = total_utility + test_function(i)

    average_utility = total_utility/len(pop)
    
    return average_utility

# %%
def graph_population(pop, name):
    data = np.array([])
    
    for po in pop:
        data = np.append(data, po.fitness)


    plt.plot(data)
    plt.title(name)
    plt.xlabel("Individual")
    plt.ylabel("Fitness")
    plt.show()
    plt.close()

# %%
def graph_averages():
    height = np.array([])
    average = np.array([])
    
    for i in best_fitness:
        height = np.append(height, i)
    
    for i in average_fitness:
        average = np.append(average, i)


    plt.plot(height, label="Best")
    plt.plot(average, label="Average")
    plt.legend()
    plt.title("Generational Fitness")


    plt.xlabel("Generation")
    plt.ylabel("Fitness")
    plt.show()
    plt.close()

# %%
for x in range (0, P):
    tempgene=[]
    for y in range (0, N):
        tempgene.append( random.randint(0,1))
    newind = individual()
    newind.gene = tempgene.copy()
    population.append(newind)

# %%
def get_height(pop):
    height = 0
    for i in pop:
        if i.fitness > height:
            height = i.fitness

    return height

# %%
def test_population(population, name):
    for pop in population:
        pop.fitness = test_function(pop)
        total_utilities[name] = total_utilities[name] + pop.fitness

# %%
for g in range (0, G):



    print("Generation ", g)

## Test origonal population

    test_population(population, "origonal")
    
    
    
        # print(pop.gene, " ", pop.fitness)



## init gladiator population
    
    for i in range (0, P):
        parent1 = random.randint( 0, P-1 )
        off1 = copy.deepcopy(population[parent1])
        parent2 = random.randint( 0, P-1 )
        off2 = copy.deepcopy(population[parent2])
        if off1.fitness > off2.fitness:
            offspring.append( off1 )
        else:
            offspring.append( off2 )

    ## test gladiator population
    
    test_population(offspring, "gladiator")



## create new copies to allow for easy transfer of data

    crossover = copy.deepcopy(offspring) 
    # mutate = copy.deepcopy(offspring)

## init crossover population

    toff1 = individual()
    toff2 = individual()
    temp = individual()
    for i in range( 0, P, 2 ):
        toff1 = copy.deepcopy(crossover[i])
        toff2 = copy.deepcopy(crossover[i+1])
        temp = copy.deepcopy(crossover[i])
        crosspoint = random.randint(1,N)

        for j in range (crosspoint, N):
            toff1.gene[j] = toff2.gene[j]
            toff2.gene[j] = temp.gene[j]
            
        crossover[i] = copy.deepcopy(toff1)
        crossover[i+1] = copy.deepcopy(toff2)

    ## test crossover population

    test_population(crossover, "crosspoint")




## init mutate population

    for i in range( 0, P ):
        newind = individual()
        newind.gene = []
        for j in range( 0, N ):
            gene = crossover[i].gene[j]
            mutprob = random.random()
            # print("muteprob: ", mutprob)
            if mutprob < M:
                if( gene == 1):
                    gene = 0
                else:
                    gene = 1
            newind.gene.append(gene)
            
        mutate.append(newind)

    ## test mutate population

    test_population(mutate, "mutate")

    







    # graph_population(population, "Origonal")
    # graph_population(offspring, "Offspring Gladiator")
    # graph_population(crossover, "Offspring Crossover")
    # graph_population(mutate, "Offspring Mutation")

    print("Best fitness: ", best_fitness[g-1])
    print("Average fitness: ", average_fitness[g-1])
    print("Total utilities: ", total_utilities)

## copy most fit population to next generation


    # if (total_utilities["gladiator"] > total_utilities["crosspoint"]):
    #     if (total_utilities["gladiator"] > total_utilities["mutate"]):

    #         if (total_utilities["origonal"] > total_utilities["gladiator"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(offspring)
    #             print("Gladiator wins")
    #     else:

    #         if (total_utilities["origonal"] > total_utilities["mutate"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(mutate)
    #             print("Mutate wins")
    # else:
    #     if (total_utilities["crosspoint"] > total_utilities["mutate"]):
    #         if(total_utilities["origonal"] > total_utilities["crosspoint"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(crossover)
    #             print("Crossover wins")
    #     else:
    #         if(total_utilities["origonal"] > total_utilities["mutate"]):
    #             population = copy.deepcopy(population)
    #             print("Origonal wins")
    #         else:
    #             population = copy.deepcopy(mutate)
    #             print("Mutate wins")



    if (total_utilities["mutate"] > total_utilities["origonal"]):
        population = copy.deepcopy(mutate)
        print("Mutate wins")
 


    ## calculate average fitness
    best_fitness[g] = get_height(population)
    average_fitness[g] = test_all(population)

    ## reset total utilities

    total_utilities = {
        "origonal": 0,
        "gladiator": 0,
        "crosspoint": 0,
        "mutate": 0
    }

    ## reset populations

    offspring = []
    crossover = []
    mutate = []



## graph average fitness

graph_averages()
# Out:
# Generation  0
# Best fitness:  0.0
# Average fitness:  0.0
# Total utilities:  {'origonal': 1267, 'gladiator': 1383, 'crosspoint': 1383, 'mutate': 1356}
# Mutate wins
# Generation  1
# Best fitness:  36.0
# Average fitness:  27.12
# Total utilities:  {'origonal': 1356, 'gladiator': 1493, 'crosspoint': 1493, 'mutate': 1460}
# Mutate wins
# Generation  2
# Best fitness:  38.0
# Average fitness:  29.2
# Total utilities:  {'origonal': 1460, 'gladiator': 1565, 'crosspoint': 1565, 'mutate': 1548}
# Mutate wins
# Generation  3
# Best fitness:  37.0
# Average fitness:  30.96
# Total utilities:  {'origonal': 1548, 'gladiator': 1630, 'crosspoint': 1630, 'mutate': 1591}
# Mutate wins
# Generation  4
# Best fitness:  37.0
# Average fitness:  31.82
# Total utilities:  {'origonal': 1591, 'gladiator': 1673, 'crosspoint': 1673, 'mutate': 1639}
# Mutate wins
# Generation  5
# Best fitness:  40.0
# Average fitness:  32.78
# Total utilities:  {'origonal': 1639, 'gladiator': 1719, 'crosspoint': 1719, 'mutate': 1687}
# Mutate wins
# Generation  6
# Best fitness:  39.0
# Average fitness:  33.74
# Total utilities:  {'origonal': 1687, 'gladiator': 1757, 'crosspoint': 1757, 'mutate': 1732}
# Mutate wins
# Generation  7
# Best fitness:  40.0
# Average fitness:  34.64
# Total utilities:  {'origonal': 1732, 'gladiator': 1807, 'crosspoint': 1807, 'mutate': 1775}
# Mutate wins
# Generation  8
# Best fitness:  41.0
# Average fitness:  35.5
# Total utilities:  {'origonal': 1775, 'gladiator': 1838, 'crosspoint': 1838, 'mutate': 1799}
# Mutate wins
# Generation  9
# Best fitness:  43.0
# Average fitness:  35.98
# Total utilities:  {'origonal': 1799, 'gladiator': 1878, 'crosspoint': 1878, 'mutate': 1829}
# Mutate wins
# Generation  10
# Best fitness:  43.0
# Average fitness:  36.58
# Total utilities:  {'origonal': 1829, 'gladiator': 1919, 'crosspoint': 1919, 'mutate': 1905}
# Mutate wins
# Generation  11
# Best fitness:  43.0
# Average fitness:  38.1
# Total utilities:  {'origonal': 1905, 'gladiator': 1965, 'crosspoint': 1965, 'mutate': 1918}
# Mutate wins
# Generation  12
# Best fitness:  43.0
# Average fitness:  38.36
# Total utilities:  {'origonal': 1918, 'gladiator': 1986, 'crosspoint': 1986, 'mutate': 1946}
# Mutate wins
# Generation  13
# Best fitness:  43.0
# Average fitness:  38.92
# Total utilities:  {'origonal': 1946, 'gladiator': 2003, 'crosspoint': 2003, 'mutate': 1970}
# Mutate wins
# Generation  14
# Best fitness:  43.0
# Average fitness:  39.4
# Total utilities:  {'origonal': 1970, 'gladiator': 2021, 'crosspoint': 2021, 'mutate': 1970}
# Generation  15
# Best fitness:  43.0
# Average fitness:  39.4
# Total utilities:  {'origonal': 1970, 'gladiator': 2016, 'crosspoint': 2016, 'mutate': 1968}
# Generation  16
# Best fitness:  43.0
# Average fitness:  39.4
# Total utilities:  {'origonal': 1970, 'gladiator': 2016, 'crosspoint': 2016, 'mutate': 1955}
# Generation  17
# Best fitness:  43.0
# Average fitness:  39.4
# Total utilities:  {'origonal': 1970, 'gladiator': 2026, 'crosspoint': 2026, 'mutate': 1988}
# Mutate wins
# Generation  18
# Best fitness:  43.0
# Average fitness:  39.76
# Total utilities:  {'origonal': 1988, 'gladiator': 2027, 'crosspoint': 2027, 'mutate': 1977}
# Generation  19
# Best fitness:  43.0
# Average fitness:  39.76
# Total utilities:  {'origonal': 1988, 'gladiator': 2028, 'crosspoint': 2028, 'mutate': 1987}
# Generation  20
# Best fitness:  43.0
# Average fitness:  39.76
# Total utilities:  {'origonal': 1988, 'gladiator': 2026, 'crosspoint': 2026, 'mutate': 2001}
# Mutate wins
# Generation  21
# Best fitness:  44.0
# Average fitness:  40.02
# Total utilities:  {'origonal': 2001, 'gladiator': 2047, 'crosspoint': 2047, 'mutate': 1982}
# Generation  22
# Best fitness:  44.0
# Average fitness:  40.02
# Total utilities:  {'origonal': 2001, 'gladiator': 2054, 'crosspoint': 2054, 'mutate': 2011}
# Mutate wins
# Generation  23
# Best fitness:  45.0
# Average fitness:  40.22
# Total utilities:  {'origonal': 2011, 'gladiator': 2071, 'crosspoint': 2071, 'mutate': 2028}
# Mutate wins
# Generation  24
# Best fitness:  45.0
# Average fitness:  40.56
# Total utilities:  {'origonal': 2028, 'gladiator': 2108, 'crosspoint': 2108, 'mutate': 2070}
# Mutate wins
# Generation  25
# Best fitness:  48.0
# Average fitness:  41.4
# Total utilities:  {'origonal': 2070, 'gladiator': 2159, 'crosspoint': 2159, 'mutate': 2095}
# Mutate wins
# Generation  26
# Best fitness:  46.0
# Average fitness:  41.9
# Total utilities:  {'origonal': 2095, 'gladiator': 2139, 'crosspoint': 2139, 'mutate': 2085}
# Generation  27
# Best fitness:  46.0
# Average fitness:  41.9
# Total utilities:  {'origonal': 2095, 'gladiator': 2152, 'crosspoint': 2152, 'mutate': 2094}
# Generation  28
# Best fitness:  46.0
# Average fitness:  41.9
# Total utilities:  {'origonal': 2095, 'gladiator': 2165, 'crosspoint': 2165, 'mutate': 2109}
# Mutate wins
# Generation  29
# Best fitness:  46.0
# Average fitness:  42.18
# Total utilities:  {'origonal': 2109, 'gladiator': 2146, 'crosspoint': 2146, 'mutate': 2095}
# Generation  30
# Best fitness:  46.0
# Average fitness:  42.18
# Total utilities:  {'origonal': 2109, 'gladiator': 2168, 'crosspoint': 2168, 'mutate': 2116}
# Mutate wins
# Generation  31
# Best fitness:  46.0
# Average fitness:  42.32
# Total utilities:  {'origonal': 2116, 'gladiator': 2162, 'crosspoint': 2162, 'mutate': 2105}
# Generation  32
# Best fitness:  46.0
# Average fitness:  42.32
# Total utilities:  {'origonal': 2116, 'gladiator': 2190, 'crosspoint': 2190, 'mutate': 2130}
# Mutate wins
# Generation  33
# Best fitness:  48.0
# Average fitness:  42.6
# Total utilities:  {'origonal': 2130, 'gladiator': 2208, 'crosspoint': 2208, 'mutate': 2135}
# Mutate wins
# Generation  34
# Best fitness:  47.0
# Average fitness:  42.7
# Total utilities:  {'origonal': 2135, 'gladiator': 2203, 'crosspoint': 2203, 'mutate': 2138}
# Mutate wins
# Generation  35
# Best fitness:  47.0
# Average fitness:  42.76
# Total utilities:  {'origonal': 2138, 'gladiator': 2222, 'crosspoint': 2222, 'mutate': 2164}
# Mutate wins
# Generation  36
# Best fitness:  48.0
# Average fitness:  43.28
# Total utilities:  {'origonal': 2164, 'gladiator': 2197, 'crosspoint': 2197, 'mutate': 2150}
# Generation  37
# Best fitness:  48.0
# Average fitness:  43.28
# Total utilities:  {'origonal': 2164, 'gladiator': 2220, 'crosspoint': 2220, 'mutate': 2144}
# Generation  38
# Best fitness:  48.0
# Average fitness:  43.28
# Total utilities:  {'origonal': 2164, 'gladiator': 2202, 'crosspoint': 2202, 'mutate': 2146}
# Generation  39
# Best fitness:  48.0
# Average fitness:  43.28
# Total utilities:  {'origonal': 2164, 'gladiator': 2230, 'crosspoint': 2230, 'mutate': 2174}
# Mutate wins
# Generation  40
# Best fitness:  48.0
# Average fitness:  43.48
# Total utilities:  {'origonal': 2174, 'gladiator': 2245, 'crosspoint': 2245, 'mutate': 2192}
# Mutate wins
# Generation  41
# Best fitness:  48.0
# Average fitness:  43.84
# Total utilities:  {'origonal': 2192, 'gladiator': 2252, 'crosspoint': 2252, 'mutate': 2190}
# Generation  42
# Best fitness:  48.0
# Average fitness:  43.84
# Total utilities:  {'origonal': 2192, 'gladiator': 2240, 'crosspoint': 2240, 'mutate': 2190}
# Generation  43
# Best fitness:  48.0
# Average fitness:  43.84
# Total utilities:  {'origonal': 2192, 'gladiator': 2268, 'crosspoint': 2268, 'mutate': 2211}
# Mutate wins
# Generation  44
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2250, 'crosspoint': 2250, 'mutate': 2198}
# Generation  45
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2263, 'crosspoint': 2263, 'mutate': 2202}
# Generation  46
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2265, 'crosspoint': 2265, 'mutate': 2208}
# Generation  47
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2262, 'crosspoint': 2262, 'mutate': 2199}
# Generation  48
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2249, 'crosspoint': 2249, 'mutate': 2193}
# Generation  49
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2262, 'crosspoint': 2262, 'mutate': 2201}
# Generation  50
# Best fitness:  47.0
# Average fitness:  44.22
# Total utilities:  {'origonal': 2211, 'gladiator': 2272, 'crosspoint': 2272, 'mutate': 2214}
# Mutate wins
# Generation  51
# Best fitness:  49.0
# Average fitness:  44.28
# Total utilities:  {'origonal': 2214, 'gladiator': 2249, 'crosspoint': 2249, 'mutate': 2183}
# Generation  52
# Best fitness:  49.0
# Average fitness:  44.28
# Total utilities:  {'origonal': 2214, 'gladiator': 2256, 'crosspoint': 2256, 'mutate': 2192}
# Generation  53
# Best fitness:  49.0
# Average fitness:  44.28
# Total utilities:  {'origonal': 2214, 'gladiator': 2279, 'crosspoint': 2279, 'mutate': 2223}
# Mutate wins
# Generation  54
# Best fitness:  48.0
# Average fitness:  44.46
# Total utilities:  {'origonal': 2223, 'gladiator': 2278, 'crosspoint': 2278, 'mutate': 2205}
# Generation  55
# Best fitness:  48.0
# Average fitness:  44.46
# Total utilities:  {'origonal': 2223, 'gladiator': 2283, 'crosspoint': 2283, 'mutate': 2212}
# Generation  56
# Best fitness:  48.0
# Average fitness:  44.46
# Total utilities:  {'origonal': 2223, 'gladiator': 2270, 'crosspoint': 2270, 'mutate': 2215}
# Generation  57
# Best fitness:  48.0
# Average fitness:  44.46
# Total utilities:  {'origonal': 2223, 'gladiator': 2265, 'crosspoint': 2265, 'mutate': 2226}
# Mutate wins
# Generation  58
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2272, 'crosspoint': 2272, 'mutate': 2197}
# Generation  59
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2270, 'crosspoint': 2270, 'mutate': 2206}
# Generation  60
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2260, 'crosspoint': 2260, 'mutate': 2183}
# Generation  61
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2284, 'crosspoint': 2284, 'mutate': 2204}
# Generation  62
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2265, 'crosspoint': 2265, 'mutate': 2196}
# Generation  63
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2273, 'crosspoint': 2273, 'mutate': 2206}
# Generation  64
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2271, 'crosspoint': 2271, 'mutate': 2197}
# Generation  65
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2276, 'crosspoint': 2276, 'mutate': 2210}
# Generation  66
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2284, 'crosspoint': 2284, 'mutate': 2213}
# Generation  67
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2263, 'crosspoint': 2263, 'mutate': 2196}
# Generation  68
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2273, 'crosspoint': 2273, 'mutate': 2210}
# Generation  69
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2273, 'crosspoint': 2273, 'mutate': 2204}
# Generation  70
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2271, 'crosspoint': 2271, 'mutate': 2206}
# Generation  71
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2269, 'crosspoint': 2269, 'mutate': 2219}
# Generation  72
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2264, 'crosspoint': 2264, 'mutate': 2206}
# Generation  73
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2289, 'crosspoint': 2289, 'mutate': 2219}
# Generation  74
# Best fitness:  47.0
# Average fitness:  44.52
# Total utilities:  {'origonal': 2226, 'gladiator': 2293, 'crosspoint': 2293, 'mutate': 2237}
# Mutate wins
# Generation  75
# Best fitness:  49.0
# Average fitness:  44.74
# Total utilities:  {'origonal': 2237, 'gladiator': 2295, 'crosspoint': 2295, 'mutate': 2241}
# Mutate wins
# Generation  76
# Best fitness:  49.0
# Average fitness:  44.82
# Total utilities:  {'origonal': 2241, 'gladiator': 2289, 'crosspoint': 2289, 'mutate': 2220}
# Generation  77
# Best fitness:  49.0
# Average fitness:  44.82
# Total utilities:  {'origonal': 2241, 'gladiator': 2284, 'crosspoint': 2284, 'mutate': 2218}
# Generation  78
# Best fitness:  49.0
# Average fitness:  44.82
# Total utilities:  {'origonal': 2241, 'gladiator': 2282, 'crosspoint': 2282, 'mutate': 2227}
# Generation  79
# Best fitness:  49.0
# Average fitness:  44.82
# Total utilities:  {'origonal': 2241, 'gladiator': 2289, 'crosspoint': 2289, 'mutate': 2235}
# Generation  80
# Best fitness:  49.0
# Average fitness:  44.82
# Total utilities:  {'origonal': 2241, 'gladiator': 2299, 'crosspoint': 2299, 'mutate': 2231}
# Generation  81
# Best fitness:  49.0
# Average fitness:  44.82
# Total utilities:  {'origonal': 2241, 'gladiator': 2309, 'crosspoint': 2309, 'mutate': 2243}
# Mutate wins
# Generation  82
# Best fitness:  49.0
# Average fitness:  44.86
# Total utilities:  {'origonal': 2243, 'gladiator': 2311, 'crosspoint': 2311, 'mutate': 2241}
# Generation  83
# Best fitness:  49.0
# Average fitness:  44.86
# Total utilities:  {'origonal': 2243, 'gladiator': 2313, 'crosspoint': 2313, 'mutate': 2252}
# Mutate wins
# Generation  84
# Best fitness:  49.0
# Average fitness:  45.04
# Total utilities:  {'origonal': 2252, 'gladiator': 2311, 'crosspoint': 2311, 'mutate': 2246}
# Generation  85
# Best fitness:  49.0
# Average fitness:  45.04
# Total utilities:  {'origonal': 2252, 'gladiator': 2308, 'crosspoint': 2308, 'mutate': 2273}
# Mutate wins
# Generation  86
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2324, 'crosspoint': 2324, 'mutate': 2260}
# Generation  87
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2331, 'crosspoint': 2331, 'mutate': 2264}
# Generation  88
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2306, 'crosspoint': 2306, 'mutate': 2234}
# Generation  89
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2317, 'crosspoint': 2317, 'mutate': 2258}
# Generation  90
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2308, 'crosspoint': 2308, 'mutate': 2243}
# Generation  91
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2318, 'crosspoint': 2318, 'mutate': 2264}
# Generation  92
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2333, 'crosspoint': 2333, 'mutate': 2269}
# Generation  93
# Best fitness:  49.0
# Average fitness:  45.46
# Total utilities:  {'origonal': 2273, 'gladiator': 2319, 'crosspoint': 2319, 'mutate': 2279}
# Mutate wins
# Generation  94
# Best fitness:  49.0
# Average fitness:  45.58
# Total utilities:  {'origonal': 2279, 'gladiator': 2323, 'crosspoint': 2323, 'mutate': 2255}
# Generation  95
# Best fitness:  49.0
# Average fitness:  45.58
# Total utilities:  {'origonal': 2279, 'gladiator': 2328, 'crosspoint': 2328, 'mutate': 2258}
# Generation  96
# Best fitness:  49.0
# Average fitness:  45.58
# Total utilities:  {'origonal': 2279, 'gladiator': 2331, 'crosspoint': 2331, 'mutate': 2268}
# Generation  97
# Best fitness:  49.0
# Average fitness:  45.58
# Total utilities:  {'origonal': 2279, 'gladiator': 2308, 'crosspoint': 2308, 'mutate': 2239}
# Generation  98
# Best fitness:  49.0
# Average fitness:  45.58
# Total utilities:  {'origonal': 2279, 'gladiator': 2335, 'crosspoint': 2335, 'mutate': 2264}
# Generation  99
# Best fitness:  49.0
# Average fitness:  45.58
# Total utilities:  {'origonal': 2279, 'gladiator': 2324, 'crosspoint': 2324, 'mutate': 2269}
